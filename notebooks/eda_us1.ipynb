# %%
import pandas as pd

# Load dataset
df = pd.read_csv("../data/processed/final_merged.csv")

# Basic inspection
print("Shape:", df.shape)
print("\nColumns:\n", df.columns)

df.head()

# %%
# Dataset structure analysis

print("Dataset Shape:", df.shape)

print("\nColumn Names:")
for col in df.columns:
    print("-", col)

print("\nData Types:")
print(df.dtypes)

print("\nBasic Info:")
df.info()

# %%
# Summary Statistics 
print("\nSummary Statistics:")
print(df.describe())

# %%
# Identify Key Variables    
target_variable = "electricity_demand_per_capita"

key_features = [
    "temperature_change_c",
    "co2_per_capita",
    "gdp",
    "population",
    "renewables_share_elec",
    "fossil_share_elec"
]

print("Target Variable:", target_variable)
print("Key Features:", key_features)

# %%
# Check missing values
missing_df = (df.isnull().sum() / len(df)) * 100
print(missing_df.sort_values(ascending=False))
# Out:
# consumption_co2_per_capita       39.907889
# consumption_co2                  39.907889
# co2_per_gdp                      22.647177
# energy_per_gdp                   22.647177
# gdp                              22.647177
# temperature_change_c              3.684421
# co2_per_unit_energy               2.142571
# energy_per_capita                 2.142571
# renewables_share_elec             0.520625
# fossil_share_elec                 0.520625
# net_elec_imports_share_demand     0.480577
# country                           0.000000
# population                        0.000000
# year                              0.000000
# electricity_demand                0.000000
# electricity_demand_per_capita     0.000000
# electricity_generation            0.000000
# co2                               0.000000
# co2_per_capita                    0.000000
# temperature_change_from_co2       0.000000
# temperature_change_from_ghg       0.000000
# iso_code                          0.000000
# dtype: float64
